# %% [markdown]
# <a href="https://colab.research.google.com/github/juanestebanhernandez29/Ejercicios-cuaderno-sys/blob/main/Energis_y_potencia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Energía y Potencia

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sym
from sympy import *

w = 300
L = 0.01
R = 4
Imax = 2
T0 = 2*np.pi/w
N = 100

t = np.linspace(0, T0, N)
i = Imax*np.sin(w*t)
plt.plot(t,i)

# %%
Vmax = np.sqrt((R**2)+((w*L)**2))*Imax
ang = np.arctan(w*L/R)

v = Vmax*np.sin(w*t + ang)

plt.plot(t, i, label='I(t)')
plt.plot(t, v, label='V(t)')
plt.grid()
plt.legend()
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')

# %%
pi = v*i
pm = np.trapz(pi, t)/T0

plt.plot(t, i, label='I(t)')
plt.plot(t, v, label='V(t)')
plt.plot(t, pi, label='Pi(t)')
plt.plot(t, pm*np.ones(len(t)), label='Pm(t)')
plt.grid()
plt.legend()
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')

# %%
C = 0.01
Vmax = np.sqrt((R**2)+(1/((w*C)**2)))*Imax
ang = -np.arctan(1/(w*C*R))

v = Vmax*np.sin(w*t + ang)

# %%
plt.plot(t, i, label='I(t)')
plt.plot(t, v, label='V(t)')
plt.grid()
plt.legend()
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')

# %%
pi = v*i
pm = np.trapz(pi, t)/T0

plt.plot(t, i, label='I(t)')
plt.plot(t, v, label='V(t)')
plt.plot(t, pi, label='Pi(t)')
plt.plot(t, pm*np.ones(len(t)), label='Pm(t)')
plt.grid()
plt.legend()
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')

# %% [markdown]
# Ejercicio 2

# %% [markdown]
# ![WhatsApp Image 2023-09-29 at 3.58.33 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Ejercicio 3

# %%
from sympy import exp
t,T=sym.symbols('t T',Real=True)
a=sym.symbols('a',Real=True,nonzero=True,nonnegative=True)
x=exp(-a*t)*t
Ex=integrate(x**2,(t,-oo,oo))
print("Ex=",Ex)
Px=limit(integrate(x**2, (t, -T/2, T/2)) / T, T, oo)
print("Px=",Px)

# %% [markdown]
# Ejercicio 4

# %%
t, B, T =symbols("t B T ", Real=True)

parte1 = (1, (0 <= t) & (t <= T/4))
parte2 = (-1, (T/4 < t) & (t <= (3*T)/4))
parte3 = (1, ((3*T)/4 < t) & (t <= T))

x2 = sym.Piecewise(parte1, parte2, parte3)
Wo = 2*sym.pi/T
x1 = sym.cos(Wo*t)

# %%
A = 1
x2 = A*(sym.Heaviside(t) - sym.Heaviside(t-T/4)) -  A*(sym.Heaviside(t-T/4) - sym.Heaviside(t-3*T/4)) +  A*(sym.Heaviside(t-3*T/4) - sym.Heaviside(t-T))
x2

# %%
P1 = (1/T)*sym.integrate(x1**2, (t, 0, T))
P3 = (1/T)*sym.integrate(A**2, (t, 0, T))
P2 = -(2/T)*(sym.integrate(x1*A, (t, 0, T/4))-sym.integrate(x1*A, (t, T/4,3*T/4))+sym.integrate(x1*A, (t, 3*T/4,T)))
P_ = P1 + P2 + P3
P_

# %%
p1 = sym.plot(x1.subs({B:1,T:2}), (t, 0, 2), ylim=[-2.2, 2.2], ylabel=r'$x(t)$', xlabel = '$t$', show=False);
p2 = sym.plot(x2.subs({A:1,T:2}), (t, 0, 2), ylim=[-2.2, 2.2], ylabel=r'$x(t)$',show=False);

p1.extend(p2)#se extiende los gráficos sobre una misma figura
p1.show()

# %% [markdown]
# Ejercicio 5

# %% [markdown]
# ![WhatsApp Image 2023-09-29 at 3.58.48 PM.jpeg](data:image/jpeg;base64,...)
